# %%
from plotter import *

# %%
import pandas as pd

# %%
sdt = pd.read_csv('cwurData.csv')

# %%
sd = plotter(sdt)

# %%
sd.sbs_chart('country','year')

# %%
sd.radial_plot_profile(20,[ 'alumni_employment','quality_of_faculty','publications', 'influence', 'citations', 'broad_impact'],'world_rank')

# %%
sd.table.iloc[20,:]
# Out:
# world_rank                                  21
# institution             Rockefeller University
# country                                    USA
# national_rank                               15
# quality_of_education                         1
# alumni_employment                          101
# quality_of_faculty                          16
# publications                               101
# influence                                   28
# citations                                   96
# broad_impact                               NaN
# patents                                    101
# score                                    61.74
# year                                      2012
# Name: 20, dtype: object
